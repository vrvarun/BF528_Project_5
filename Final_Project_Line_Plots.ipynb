# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mito=pd.read_csv('Mito.csv')
sarc=pd.read_csv('Sarc.csv')
cc=pd.read_csv('Cell_Cyle.csv')
#read in fpkm data for genes

# %%
order1=['V10','V9','V5','V7','V2']
order2=['V10','V4','V6','V8','V3']
#order of columns for graphs

# %%
for i in range(len(sarc)):
    plt.scatter(['P0','P4','P7','AD'],sarc[order1].iloc[i][1:])
    plt.plot(['P0','P4','P7','AD'],sarc[order1].iloc[i][1:])
plt.legend(sarc['V10'],loc=[1.1, 0.5])
plt.title('Sarc_01')
#scatter plot, then connect on the points from the dataset in the order specified
# Out:
# Text(0.5, 1.0, 'Sarc_01')

# %%
for i in range(len(mito)):
    plt.scatter(['P0','P4','P7','AD'],mito[order1].iloc[i][1:])
    plt.plot(['P0','P4','P7','AD'],mito[order1].iloc[i][1:])
plt.legend(mito['V10'],loc=[1.1, 0.5])
plt.title('Mito_01')
#scatter plot, then connect on the points from the dataset in the order specified
# Out:
# Text(0.5, 1.0, 'Mito_01')

# %%
for i in range(len(cc)):
    plt.scatter(['P0','P4','P7','AD'],cc[order1].iloc[i][1:])
    plt.plot(['P0','P4','P7','AD'],cc[order1].iloc[i][1:])
plt.legend(cc['V10'],loc=[1.1, 0.5])
plt.title('CC_01')
#scatter plot, then connect on the points from the dataset in the order specified
# Out:
# Text(0.5, 1.0, 'CC_01')

# %%
for i in range(len(sarc)):
    plt.scatter(['P0_2','P4_2','P7_2','AD_2'],sarc[order2].iloc[i][1:])
    plt.plot(['P0_2','P4_2','P7_2','AD_2'],sarc[order2].iloc[i][1:])
plt.legend(sarc['V10'],loc=[1.1, 0.5])
plt.title('Sarc_02')
#scatter plot, then connect on the points from the dataset in the order specified
# Out:
# Text(0.5, 1.0, 'Sarc_02')

# %%
for i in range(len(mito)):
    plt.scatter(['P0_2','P4_2','P7_2','AD_2'],mito[order2].iloc[i][1:])
    plt.plot(['P0_2','P4_2','P7_2','AD_2'],mito[order2].iloc[i][1:])
plt.legend(mito['V10'],loc=[1.1, 0.5])
plt.title('Mito_02')
#scatter plot, then connect on the points from the dataset in the order specified
# Out:
# Text(0.5, 1.0, 'Mito_02')

# %%
for i in range(len(cc)):
    plt.scatter(['P0_2','P4_2','P7_2','AD_2'],cc[order2].iloc[i][1:])
    plt.plot(['P0_2','P4_2','P7_2','AD_2'],cc[order2].iloc[i][1:])
plt.legend(cc['V10'],loc=[1.1, 0.5])
plt.title('CC_02')
#scatter plot, then connect on the points from the dataset in the order specified
# Out:
# Text(0.5, 1.0, 'CC_02')
